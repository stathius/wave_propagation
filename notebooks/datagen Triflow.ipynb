# %%
import triflow as trf
import numpy as np
import scipy.signal
import os
from PIL import Image
import random
import time
import copy
import matplotlib.pyplot as plt
from sys import argv
import argparse


"""
Wilhelm Sorteberg, 2018
wilhelm@sorteberg.eu

"""

def is_interactive():
    import __main__ as main
    return not hasattr(main, '__file__')

def get_args():
    """
    Returns a namedtuple with arguments extracted from the command line.
    :return: A namedtuple with arguments
    """
    parser = argparse.ArgumentParser()

    parser.add_argument('--location', type=str, default='./debug', help='Folder to save the files')
    parser.add_argument('--azimuth', type=int, default=45, help='Lighting angle')
    parser.add_argument('--viewing_angle', type=int, default=20, help='Viewing angle')
    parser.add_argument('--container_size_min', type=int, default=10, help='How big the water container (box) is')
    parser.add_argument('--container_size_max', type=int, default=20, help='How big the water container (box) is')
    parser.add_argument('--water_depth', type=int, default=10)
    parser.add_argument('--initial_stimuli', type=int, default=10, help='Strength of initial stimuli')
    parser.add_argument('--coriolis_force', type=float, default=0.0, help='Coriolis force coefficient')
    parser.add_argument('--water_viscocity', type=int, default=1e-6, help='Water viscocity')

    parser.add_argument('--total_time', type=float, default=1.0, help='Total sequence time in seconds')
    parser.add_argument('--dt', type=float, default=0.01, help='Time interval between frames in seconds')
    parser.add_argument('--image_size', type=int, default=184, help='Pixel size of the output images')
    parser.add_argument('--data_points', type=int, default=10, help='How many sequences to create)

    args = parser.parse_args()

    return args


if is_interactive():
    # %matplotlib notebook
    plot = True
    location = "./debug"
    azimuth = 45             # 45
    viewing_angle = 20       # 20
    container_size_min = 10  # 10
    container_size_max = 20  # 20
    water_depth = 10         # 10
    initial_stimulus = 1     # 1
    pars = {"f": 0.0, "nu": 10e-6} # 0, 10e-6
    TIME = 1.0                 # 1
    dt = 0.01                # 0.01
    data_points = 500
    Nx = Ny = 184
else:
    plot = False
    
    
def hillshade(array, azimuth, angle_altitude):

    x, y = np.gradient(array)
    slope = np.pi / 2. - np.arctan(np.sqrt(x * x + y * y))
    aspect = np.arctan2(-x, y)
    azimuthrad = azimuth * np.pi / 180.
    altituderad = angle_altitude * np.pi / 180.

    shaded = np.sin(altituderad) * np.sin(slope) + \
             np.cos(altituderad) * np.cos(slope) * \
             np.cos(azimuthrad - aspect)
    the_range = np.sort(np.reshape(shaded, -1))
    minimum = the_range[int(0.005 * len(the_range))]
    maximum = the_range[int(0.995 * len(the_range))]
    norm_shaded = (shaded - minimum) / (maximum - minimum)
    norm_shaded = np.clip(norm_shaded, 0, 1)
    return 255 * norm_shaded


class NonConservative_ShallowWater:
    @staticmethod
    def F(fields, pars):
        Ffields = fields.copy()
        x = fields["x"].values
        h = fields["h"].values
        u = fields["u"].values
        v = fields["v"].values
        H = fields["H"].values

        delta_x = x.ptp() / (x.size - 1)
        delta_y = y.ptp() / (y.size - 1)

        def dx(U):
            return (np.roll(U, -1, axis=1) - np.roll(U, 1, axis=1)) / (2 * delta_x)

        def dy(U):
            return (np.roll(U, -1, axis=0) - np.roll(U, 1, axis=0)) / (2 * delta_y)

        def dxx(U):
            return (np.roll(U, 1, axis=1) - 2 * U + np.roll(U, -1, axis=1)) / (delta_x**2)

        def dyy(U):
            return (np.roll(U, 1, axis=0) - 2 * U + np.roll(U, -1, axis=0)) / (delta_y**2)

        eta = h + H
        visc = lambda var: pars["nu"] * (dxx(var) + dyy(var))
        dth = -(dx(u * eta) + dy(v * eta))
        dtu = -(u * dx(u) + v * dy(u)) + pars["f"] * v - 9.81 * dx(h) + visc(u)
        dtv = -(u * dx(v) + v * dy(v)) - pars["f"] * u - 9.81 * dy(h) + visc(v)

        Ffields["h"][:] = dth
        Ffields["u"][:] = dtu
        Ffields["v"][:] = dtv
        return Ffields.uflat
    _indep_vars = ["x", "y"]
    fields_template = trf.core.fields.BaseFields.factory(("x", "y"),
                                                         [("h", ("x", "y")),
                                                          ("u", ("x", "y")),
                                                          ("v", ("x", "y"))],
                                                         [("H", ("x", "y"))])


def solid_wall(t, fields, pars):
    fields["u"][:, 0] = 0.
    fields["u"][:, -1] = 0
    fields["u"][0, :] = 0
    fields["u"][-1, :] = 0
    fields["v"][:, 0] = 0
    fields["v"][:, -1] = 0
    fields["v"][0, :] = 0
    fields["v"][-1, :] = 0
    fields["h"][:, 0] = copy.copy(fields["h"][:, 1])
    fields["h"][:, -1] = copy.copy(fields["h"][:, -2])
    fields["h"][0, :] = copy.copy(fields["h"][1, :])
    fields["h"][-1, :] = copy.copy(fields["h"][-2, :])
    return fields, pars


def constrict(val, min_val, max_val):
    if val < min_val:
        return min_val
    elif val > max_val:
        return max_val
    else:
        return val

if plot:
    fig = plt.figure(figsize=(6, 6))
    image_real = np.zeros((Nx, Ny))
    img = plt.imshow(image_real, cmap='gray')
    plt.draw()
    plt.show(block=False)

if not os.path.isdir(location):
    os.mkdir(location)

model = NonConservative_ShallowWater()

while len(os.listdir(location)) < data_points:
    MaxRoll = Nx / 2 - 10
    size = random.uniform(container_size_min, container_size_max) # Container size
    x_roll = random.randint(-MaxRoll, MaxRoll)
    y_roll = random.randint(-MaxRoll, MaxRoll)
    x = np.linspace(0, size, Nx)           # Physical domain
    y = np.linspace(0, size, Ny)           # Physical domain
    u = np.zeros((Nx, Ny))          # x velocity
    v = np.zeros((Nx, Ny))          # y velocity    #Can add +2 to add a general underlying velocity
    h = np.zeros((3 * Nx, 3 * Ny)) + (scipy.signal.windows.gaussian(3 * Nx, 5) * scipy.signal.windows.gaussian(3 * Ny, 5)[:, None]) * initial_stimulus
    h = np.roll(h, x_roll, axis=1)        # Drop x position
    h = np.roll(h, y_roll, axis=0)        # Drop Y position
    h = h[Nx: 2 * Nx, Ny: 2 * Ny]
    H = np.ones((Nx, Ny)) * water_depth
    init_fields = model.fields_template(x=x, y=y, h=h, u=u, v=v, H=H)

    scheme = trf.schemes.scipy_ode(model, integrator="dopri5")

    Set_Name = "Size-{:.2f}_Centre_x{},y{}".format(size, str(x_roll).zfill(4), str(y_roll).zfill(4))
    if not os.path.isdir(location + "/" + Set_Name):
        os.mkdir(location + "/" + Set_Name)

    for i in range(0, int(TIME / dt)):
        if i == 0:
            new_t, new_fields = scheme(t=0, fields=init_fields.copy(), dt=dt, pars=pars, hook=solid_wall)
        else:
            new_t, new_fields = scheme(t=new_t, fields=new_fields.copy(), dt=dt, pars=pars, hook=solid_wall)

        eta = new_fields["h"] + new_fields["H"]
        norm_eta = (eta - eta.min()) / (eta.max() - eta.min())
        im = Image.fromarray(hillshade(norm_eta, azimuth, viewing_angle))
        im = im.convert('RGB')

        number = str(i).zfill(3)

        print(location + "/" + Set_Name + "/" + "img" + number + ".jpg")
        im.save(location + "/" + Set_Name + "/" + "img" + number + ".jpg")

        if plot:
            img.set_data(im)
            fig.canvas.draw()
            plt.show(block=False)
# Out:
# <img src="data:image/png;base64,..." width="600">
# ./solid/Size-17.17_Centre_x-025,y0029/img000.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img001.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img002.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img003.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img004.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img005.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img006.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img007.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img008.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img009.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img010.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img011.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img012.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img013.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img014.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img015.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img016.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img017.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img018.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img019.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img020.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img021.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img022.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img023.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img024.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img025.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img026.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img027.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img028.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img029.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img030.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img031.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img032.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img033.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img034.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img035.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img036.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img037.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img038.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img039.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img040.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img041.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img042.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img043.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img044.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img045.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img046.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img047.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img048.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img049.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img050.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img051.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img052.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img053.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img054.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img055.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img056.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img057.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img058.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img059.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img060.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img061.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img062.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img063.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img064.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img065.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img066.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img067.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img068.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img069.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img070.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img071.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img072.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img073.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img074.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img075.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img076.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img077.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img078.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img079.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img080.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img081.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img082.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img083.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img084.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img085.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img086.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img087.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img088.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img089.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img090.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img091.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img092.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img093.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img094.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img095.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img096.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img097.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img098.jpg
# ./solid/Size-17.17_Centre_x-025,y0029/img099.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img000.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img001.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img002.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img003.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img004.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img005.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img006.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img007.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img008.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img009.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img010.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img011.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img012.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img013.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img014.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img015.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img016.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img017.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img018.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img019.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img020.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img021.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img022.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img023.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img024.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img025.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img026.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img027.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img028.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img029.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img030.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img031.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img032.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img033.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img034.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img035.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img036.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img037.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img038.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img039.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img040.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img041.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img042.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img043.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img044.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img045.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img046.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img047.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img048.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img049.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img050.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img051.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img052.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img053.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img054.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img055.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img056.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img057.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img058.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img059.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img060.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img061.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img062.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img063.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img064.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img065.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img066.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img067.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img068.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img069.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img070.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img071.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img072.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img073.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img074.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img075.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img076.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img077.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img078.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img079.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img080.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img081.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img082.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img083.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img084.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img085.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img086.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img087.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img088.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img089.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img090.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img091.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img092.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img093.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img094.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img095.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img096.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img097.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img098.jpg
# ./solid/Size-10.75_Centre_x-041,y-008/img099.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img000.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img001.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img002.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img003.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img004.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img005.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img006.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img007.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img008.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img009.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img010.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img011.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img012.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img013.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img014.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img015.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img016.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img017.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img018.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img019.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img020.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img021.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img022.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img023.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img024.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img025.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img026.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img027.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img028.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img029.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img030.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img031.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img032.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img033.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img034.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img035.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img036.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img037.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img038.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img039.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img040.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img041.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img042.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img043.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img044.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img045.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img046.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img047.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img048.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img049.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img050.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img051.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img052.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img053.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img054.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img055.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img056.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img057.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img058.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img059.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img060.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img061.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img062.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img063.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img064.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img065.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img066.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img067.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img068.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img069.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img070.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img071.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img072.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img073.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img074.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img075.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img076.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img077.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img078.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img079.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img080.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img081.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img082.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img083.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/img084.jpg
# ./solid/Size-18.44_Centre_x-067,y-080/
jpg
# ./solid/Size-13.10_Centre_x0014,y-041/img095.jpg
# ./solid/Size-13.10_Centre_x0014,y-041/img096.jpg
# ./solid/Size-13.10_Centre_x0014,y-041/img097.jpg
# ./solid/Size-13.10_Centre_x0014,y-041/img098.jpg
# ./solid/Size-13.10_Centre_x0014,y-041/img099.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img000.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img001.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img002.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img003.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img004.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img005.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img006.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img007.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img008.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img009.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img010.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img011.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img012.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img013.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img014.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img015.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img016.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img017.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img018.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img019.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img020.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img021.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img022.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img023.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img024.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img025.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img026.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img027.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img028.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img029.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img030.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img031.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img032.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img033.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img034.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img035.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img036.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img037.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img038.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img039.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img040.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img041.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img042.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img043.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img044.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img045.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img046.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img047.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img048.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img049.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img050.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img051.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img052.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img053.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img054.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img055.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img056.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img057.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img058.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img059.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img060.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img061.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img062.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img063.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img064.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img065.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img066.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img067.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img068.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img069.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img070.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img071.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img072.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img073.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img074.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img075.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img076.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img077.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img078.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img079.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img080.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img081.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img082.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img083.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img084.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img085.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img086.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img087.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img088.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img089.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img090.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img091.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img092.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img093.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img094.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img095.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img096.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img097.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img098.jpg
# ./solid/Size-12.42_Centre_x0072,y-031/img099.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img000.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img001.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img002.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img003.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img004.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img005.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img006.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img007.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img008.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img009.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img010.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img011.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img012.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img013.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img014.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img015.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img016.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img017.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img018.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img019.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img020.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img021.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img022.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img023.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img024.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img025.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img026.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img027.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img028.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img029.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img030.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img031.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img032.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img033.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img034.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img035.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img036.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img037.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img038.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img039.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img040.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img041.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img042.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img043.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img044.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img045.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img046.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img047.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img048.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img049.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img050.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img051.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img052.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img053.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img054.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img055.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img056.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img057.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img058.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img059.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img060.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img061.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img062.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img063.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img064.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img065.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img066.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img067.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img068.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img069.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img070.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img071.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img072.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img073.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img074.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img075.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img076.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img077.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img078.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img079.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img080.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img081.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img082.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img083.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img084.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img085.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img086.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img087.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img088.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img089.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img090.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img091.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img092.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img093.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img094.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img095.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img096.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img097.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img098.jpg
# ./solid/Size-12.51_Centre_x0044,y0035/img099.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img000.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img001.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img002.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img003.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img004.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img005.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img006.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img007.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img008.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img009.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img010.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img011.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img012.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img013.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img014.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img015.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img016.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img017.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img018.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img019.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img020.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img021.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img022.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img023.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img024.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img025.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img026.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img027.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img028.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img029.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img030.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img031.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img032.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img033.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img034.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img035.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img036.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img037.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img038.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img039.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img040.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img041.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img042.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img043.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img044.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img045.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img046.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img047.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img048.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img049.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img050.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img051.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img052.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img053.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img054.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img055.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img056.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img057.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img058.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img059.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img060.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img061.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img062.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img063.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img064.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img065.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img066.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img067.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img068.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img069.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img070.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img071.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img072.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img073.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img074.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img075.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img076.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img077.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img078.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img079.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img080.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img081.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img082.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img083.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img084.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img085.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img086.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img087.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img088.jpg
# ./solid/Size-13.92_Centre_x-005,y0052/img089.jpg
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-562ba9b8464d> in <module>
#     178
#     179         print(location + "/" + Set_Name + "/" + "img" + number + ".jpg")
# --> 180         im.save(location + "/" + Set_Name + "/" + "img" + number + ".jpg")
#     181
#     182         if plot:
#
# ~/anaconda3/envs/mlp/lib/python3.6/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    1989                 # Open also for reading ("+"), because TIFF save_all
#    1990                 # writer needs to go back and edit the written data.
# -> 1991                 fp = builtins.open(filename, "w+b")
#    1992
#    1993         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: './solid/Size-13.92_Centre_x-005,y0052/img089.jpg'
